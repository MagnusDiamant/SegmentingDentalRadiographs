# %%
pip install imantics
# Out:
# Collecting imantics
#   Downloading imantics-0.1.12.tar.gz (13 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from imantics) (1.22.4)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.10/dist-packages (from imantics) (4.7.0.72)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from imantics) (4.9.2)
# Collecting xmljson (from imantics)
#   Downloading xmljson-0.2.1-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: imantics
#   Building wheel for imantics (setup.py) ... done
#   Created wheel for imantics: filename=imantics-0.1.12-py3-none-any.whl size=16015 sha256=6f6055081d71c0bc92e6064dd726bbc957cc681b3b78ee10a240d7605ff62752
#   Stored in directory: /root/.cache/pip/wheels/56/6a/be/4c60e88b14abec4e93234a1f7f91ce8abe1ae88a2b3eaad3ac
# Successfully built imantics
# Installing collected packages: xmljson, imantics
# Successfully installed imantics-0.1.12 xmljson-0.2.1

# %%
pip install colorama
# Out:
# Collecting colorama
#   Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Installing collected packages: colorama
# Successfully installed colorama-0.4.6

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
import tensorflow as tf
import json
import os
import imantics
from PIL import Image
from skimage.transform import resize
import random
from sklearn.model_selection import train_test_split
from tensorflow.keras import mixed_precision
# %matplotlib inline

from colorama import Style, Fore
blk = Style.BRIGHT + Fore.BLACK
red = Style.BRIGHT + Fore.RED
blu = Style.BRIGHT + Fore.BLUE
res = Style.RESET_ALL

# %%
base_dir = '/content/drive/MyDrive/buildings'
masks_dir = f'{base_dir}/train_masks/masks'
images_dir = f'{base_dir}/train_images/imgs'

# %%
image_size = 1920

# %%
images_listdir = os.listdir(images_dir)
print(f"{blk}Dataset contains {red}{len(images_listdir)} {blk}images")
# Out:
# Dataset contains 19 images

# %%
def read_image(path):
    img = cv2.imread(path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    img = cv2.resize(img, (image_size, image_size))
    return img

# %%
def read_mask(path):
    mask = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
    mask = mask > 0
    return mask

# %%
first9images = images_listdir[:9]

# %%
rows = 3
cols = 3
fig, ax = plt.subplots(rows, cols, figsize = (12,8))

for i, ax in enumerate(ax.flat):
    if i < len(first9images):
        img = read_image(f"{images_dir}/{first9images[i]}")
        ax.set_title(f"{first9images[i]}")
        ax.imshow(img)
        ax.axis('off')

# %%
masks_listdir = os.listdir(masks_dir)
print(f"{blk}Dataset contains {red}{len(masks_listdir)} {blk}masks")
# Out:
# Dataset contains 19 masks

# %%
first9masks = masks_listdir[:9]

# %%
rows = 3
cols = 3
fig, ax = plt.subplots(rows, cols, figsize = (12,8))

for i, ax in enumerate(ax.flat):
    if i < len(first9masks):
        img = read_image(f"{masks_dir}/{first9masks[i]}")
        ax.set_title(f"{first9masks[i]}")
        ax.imshow(img)
        ax.axis('off')

# %%
images = np.zeros((len(images_listdir), image_size, image_size, 3), dtype=np.uint8)
masks = np.zeros((len(masks_listdir), image_size, image_size), dtype=bool)

for i in range(len(images_listdir)):
  cur_image = read_image(f"{images_dir}/{images_listdir[i]}")
  images[i] = cur_image

  cur_mask = read_mask(f"{masks_dir}/{images_listdir[i]}")
  masks[i] = cur_mask

# %%
images_train, images_test, masks_train, masks_test = train_test_split(images, masks, test_size=0.2, random_state=42)

print(f"{blk}== Training set shapes == \n{blk}Images : {red}{images_train.shape}\n{blk}Masks : {red}{masks_train.shape}")
print(f"{blk}== Test set shapes == \n{blk}Images : {red}{images_test.shape}\n{blk}Masks : {red}{masks_test.shape}")
# Out:
# == Training set shapes ==
# Images : (15, 1920, 1920, 3)
# Masks : (15, 1920, 1920)
# == Test set shapes ==
# Images : (4, 1920, 1920, 3)
# Masks : (4, 1920, 1920)

# %%
fig, ax = plt.subplots(rows, cols, figsize = (12,8))

for i, ax in enumerate(ax.flat):
    if i < 9:
        ax.imshow(images[i])
        ax.imshow(masks[i], alpha=0.4)
        ax.axis('off')

# %%
policy = mixed_precision.Policy('mixed_float16')
mixed_precision.set_global_policy(policy)

# %%
def conv_block(input, num_filters):
    conv = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(input)
    conv = tf.keras.layers.BatchNormalization()(conv)
    conv = tf.keras.layers.Activation("relu")(conv)
    conv = tf.keras.layers.Conv2D(num_filters, 3, padding="same")(conv)
    conv = tf.keras.layers.BatchNormalization()(conv)
    conv = tf.keras.layers.Activation("relu")(conv)
    return conv

def encoder_block(input, num_filters):
    skip = conv_block(input, num_filters)
    pool = tf.keras.layers.MaxPool2D((2, 2))(skip)
    return skip, pool

def decoder_block(input, skip, num_filters):
    up_conv = tf.keras.layers.Conv2DTranspose(num_filters, (2, 2), strides=2, padding="same")(input)
    conv = tf.keras.layers.Concatenate()([up_conv, skip])
    conv = conv_block(conv, num_filters)
    return conv

def Unet(input_shape):
    inputs = tf.keras.layers.Input(input_shape)

    skip1, pool1 = encoder_block(inputs, 64)
    skip2, pool2 = encoder_block(pool1, 128)
    skip3, pool3 = encoder_block(pool2, 256)
    skip4, pool4 = encoder_block(pool3, 512)
    skip5, pool5 = encoder_block(pool4, 1024)
    skip6, pool6 = encoder_block(pool5, 2048)

    bridge = conv_block(pool6, 4096)

    decode1 = decoder_block(bridge, skip6, 2048)
    decode2 = decoder_block(decode1, skip5, 1024)
    decode3 = decoder_block(decode2, skip4, 512)
    decode4 = decoder_block(decode3, skip3, 256)
    decode5 = decoder_block(decode4, skip2, 128)
    decode6 = decoder_block(decode5, skip1, 64)

    outputs = tf.keras.layers.Conv2D(1, 1, padding="same", activation="sigmoid")(decode6)

    model = tf.keras.models.Model(inputs, outputs, name="U-Net")
    return model

unet_model = Unet((image_size, image_size, 3))
unet_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
unet_model.summary()
# Out:
# Model: "U-Net"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 1920, 1920,  0           []
#                                  3)]
#
#  conv2d_23 (Conv2D)             (None, 1920, 1920,   1792        ['input_2[0][0]']
#                                 64)
#
#  batch_normalization_22 (BatchN  (None, 1920, 1920,   256        ['conv2d_23[0][0]']
#  ormalization)                  64)
#
#  activation_22 (Activation)     (None, 1920, 1920,   0           ['batch_normalization_22[0][0]']
#                                 64)
#
#  conv2d_24 (Conv2D)             (None, 1920, 1920,   36928       ['activation_22[0][0]']
#                                 64)
#
#  batch_normalization_23 (BatchN  (None, 1920, 1920,   256        ['conv2d_24[0][0]']
#  ormalization)                  64)
#
#  activation_23 (Activation)     (None, 1920, 1920,   0           ['batch_normalization_23[0][0]']
#                                 64)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 960, 960, 64  0          ['activation_23[0][0]']
#                                 )
#
#  conv2d_25 (Conv2D)             (None, 960, 960, 12  73856       ['max_pooling2d_5[0][0]']
#                                 8)
#
#  batch_normalization_24 (BatchN  (None, 960, 960, 12  512        ['conv2d_25[0][0]']
#  ormalization)                  8)
#
#  activation_24 (Activation)     (None, 960, 960, 12  0           ['batch_normalization_24[0][0]']
#                                 8)
#
#  conv2d_26 (Conv2D)             (None, 960, 960, 12  147584      ['activation_24[0][0]']
#                                 8)
#
#  batch_normalization_25 (BatchN  (None, 960, 960, 12  512        ['conv2d_26[0][0]']
#  ormalization)                  8)
#
#  activation_25 (Activation)     (None, 960, 960, 12  0           ['batch_normalization_25[0][0]']
#                                 8)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 480, 480, 12  0          ['activation_25[0][0]']
#                                 8)
#
#  conv2d_27 (Conv2D)             (None, 480, 480, 25  295168      ['max_pooling2d_6[0][0]']
#                                 6)
#
#  batch_normalization_26 (BatchN  (None, 480, 480, 25  1024       ['conv2d_27[0][0]']
#  ormalization)                  6)
#
#  activation_26 (Activation)     (None, 480, 480, 25  0           ['batch_normalization_26[0][0]']
#                                 6)
#
#  conv2d_28 (Conv2D)             (None, 480, 480, 25  590080      ['activation_26[0][0]']
#                                 6)
#
#  batch_normalization_27 (BatchN  (None, 480, 480, 25  1024       ['conv2d_28[0][0]']
#  ormalization)                  6)
#
#  activation_27 (Activation)     (None, 480, 480, 25  0           ['batch_normalization_27[0][0]']
#                                 6)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 240, 240, 25  0          ['activation_27[0][0]']
#                                 6)
#
#  conv2d_29 (Conv2D)             (None, 240, 240, 51  1180160     ['max_pooling2d_7[0][0]']
#                                 2)
#
#  batch_normalization_28 (BatchN  (None, 240, 240, 51  2048       ['conv2d_29[0][0]']
#  ormalization)                  2)
#
#  activation_28 (Activation)     (None, 240, 240, 51  0           ['batch_normalization_28[0][0]']
#                                 2)
#
#  conv2d_30 (Conv2D)             (None, 240, 240, 51  2359808     ['activation_28[0][0]']
#                                 2)
#
#  batch_normalization_29 (BatchN  (None, 240, 240, 51  2048       ['conv2d_30[0][0]']
#  ormalization)                  2)
#
#  activation_29 (Activation)     (None, 240, 240, 51  0           ['batch_normalization_29[0][0]']
#                                 2)
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 120, 120, 51  0          ['activation_29[0][0]']
#                                 2)
#
#  conv2d_31 (Conv2D)             (None, 120, 120, 10  4719616     ['max_pooling2d_8[0][0]']
#                                 24)
#
#  batch_normalization_30 (BatchN  (None, 120, 120, 10  4096       ['conv2d_31[0][0]']
#  ormalization)                  24)
#
#  activation_30 (Activation)     (None, 120, 120, 10  0           ['batch_normalization_30[0][0]']
#                                 24)
#
#  conv2d_32 (Conv2D)             (None, 120, 120, 10  9438208     ['activation_30[0][0]']
#                                 24)
#
#  batch_normalization_31 (BatchN  (None, 120, 120, 10  4096       ['conv2d_32[0][0]']
#  ormalization)                  24)
#
#  activation_31 (Activation)     (None, 120, 120, 10  0           ['batch_normalization_31[0][0]']
#                                 24)
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 60, 60, 1024  0          ['activation_31[0][0]']
#                                 )
#
#  conv2d_33 (Conv2D)             (None, 60, 60, 2048  18876416    ['max_pooling2d_9[0][0]']
#                                 )
#
#  batch_normalization_32 (BatchN  (None, 60, 60, 2048  8192       ['conv2d_33[0][0]']
#  ormalization)                  )
#
#  activation_32 (Activation)     (None, 60, 60, 2048  0           ['batch_normalization_32[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 60, 60, 2048  37750784    ['activation_32[0][0]']
#                                 )
#
#  batch_normalization_33 (BatchN  (None, 60, 60, 2048  8192       ['conv2d_34[0][0]']
#  ormalization)                  )
#
#  activation_33 (Activation)     (None, 60, 60, 2048  0           ['batch_normalization_33[0][0]']
#                                 )
#
#  max_pooling2d_10 (MaxPooling2D  (None, 30, 30, 2048  0          ['activation_33[0][0]']
#  )                              )
#
#  conv2d_35 (Conv2D)             (None, 30, 30, 4096  75501568    ['max_pooling2d_10[0][0]']
#                                 )
#
#  batch_normalization_34 (BatchN  (None, 30, 30, 4096  16384      ['conv2d_35[0][0]']
#  ormalization)                  )
#
#  activation_34 (Activation)     (None, 30, 30, 4096  0           ['batch_normalization_34[0][0]']
#                                 )
#
#  conv2d_36 (Conv2D)             (None, 30, 30, 4096  150999040   ['activation_34[0][0]']
#                                 )
#
#  batch_normalization_35 (BatchN  (None, 30, 30, 4096  16384      ['conv2d_36[0][0]']
#  ormalization)                  )
#
#  activation_35 (Activation)     (None, 30, 30, 4096  0           ['batch_normalization_35[0][0]']
#                                 )
#
#  conv2d_transpose_5 (Conv2DTran  (None, 60, 60, 2048  33556480   ['activation_35[0][0]']
#  spose)                         )
#
#  concatenate_5 (Concatenate)    (None, 60, 60, 4096  0           ['conv2d_transpose_5[0][0]',
#                                 )                                 'activation_33[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 60, 60, 2048  75499520    ['concatenate_5[0][0]']
#                                 )
#
#  batch_normalization_36 (BatchN  (None, 60, 60, 2048  8192       ['conv2d_37[0][0]']
#  ormalization)                  )
#
#  activation_36 (Activation)     (None, 60, 60, 2048  0           ['batch_normalization_36[0][0]']
#                                 )
#
#  conv2d_38 (Conv2D)             (None, 60, 60, 2048  37750784    ['activation_36[0][0]']
#                                 )
#
#  batch_normalization_37 (BatchN  (None, 60, 60, 2048  8192       ['conv2d_38[0][0]']
#  ormalization)                  )
#
#  activation_37 (Activation)     (None, 60, 60, 2048  0           ['batch_normalization_37[0][0]']
#                                 )
#
#  conv2d_transpose_6 (Conv2DTran  (None, 120, 120, 10  8389632    ['activation_37[0][0]']
#  spose)                         24)
#
#  concatenate_6 (Concatenate)    (None, 120, 120, 20  0           ['conv2d_transpose_6[0][0]',
#                                 48)                               'activation_31[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 120, 120, 10  18875392    ['concatenate_6[0][0]']
#                                 24)
#
#  batch_normalization_38 (BatchN  (None, 120, 120, 10  4096       ['conv2d_39[0][0]']
#  ormalization)                  24)
#
#  activation_38 (Activation)     (None, 120, 120, 10  0           ['batch_normalization_38[0][0]']
#                                 24)
#
#  conv2d_40 (Conv2D)             (None, 120, 120, 10  9438208     ['activation_38[0][0]']
#                                 24)
#
#  batch_normalization_39 (BatchN  (None, 120, 120, 10  4096       ['conv2d_40[0][0]']
#  ormalization)                  24)
#
#  activation_39 (Activation)     (None, 120, 120, 10  0           ['batch_normalization_39[0][0]']
#                                 24)
#
#  conv2d_transpose_7 (Conv2DTran  (None, 240, 240, 51  2097664    ['activation_39[0][0]']
#  spose)                         2)
#
#  concatenate_7 (Concatenate)    (None, 240, 240, 10  0           ['conv2d_transpose_7[0][0]',
#                                 24)                               'activation_29[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 240, 240, 51  4719104     ['concatenate_7[0][0]']
#                                 2)
#
#  batch_normalization_40 (BatchN  (None, 240, 240, 51  2048       ['conv2d_41[0][0]']
#  ormalization)                  2)
#
#  activation_40 (Activation)     (None, 240, 240, 51  0           ['batch_normalization_40[0][0]']
#                                 2)
#
#  conv2d_42 (Conv2D)             (None, 240, 240, 51  2359808     ['activation_40[0][0]']
#                                 2)
#
#  batch_normalization_41 (BatchN  (None, 240, 240, 51  2048       ['conv2d_42[0][0]']
#  ormalization)                  2)
#
#  activation_41 (Activation)     (None, 240, 240, 51  0           ['batch_normalization_41[0][0]']
#                                 2)
#
#  conv2d_transpose_8 (Conv2DTran  (None, 480, 480, 25  524544     ['activation_41[0][0]']
#  spose)                         6)
#
#  concatenate_8 (Concatenate)    (None, 480, 480, 51  0           ['conv2d_transpose_8[0][0]',
#                                 2)                                'activation_27[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 480, 480, 25  1179904     ['concatenate_8[0][0]']
#                                 6)
#
#  batch_normalization_42 (BatchN  (None, 480, 480, 25  1024       ['conv2d_43[0][0]']
#  ormalization)                  6)
#
#  activation_42 (Activation)     (None, 480, 480, 25  0           ['batch_normalization_42[0][0]']
#                                 6)
#
#  conv2d_44 (Conv2D)             (None, 480, 480, 25  590080      ['activation_42[0][0]']
#                                 6)
#
#  batch_normalization_43 (BatchN  (None, 480, 480, 25  1024       ['conv2d_44[0][0]']
#  ormalization)                  6)
#
#  activation_43 (Activation)     (None, 480, 480, 25  0           ['batch_normalization_43[0][0]']
#                                 6)
#
#  conv2d_transpose_9 (Conv2DTran  (None, 960, 960, 12  131200     ['activation_43[0][0]']
#  spose)                         8)
#
#  concatenate_9 (Concatenate)    (None, 960, 960, 25  0           ['conv2d_transpose_9[0][0]',
#                                 6)                                'activation_25[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 960, 960, 12  295040      ['concatenate_9[0][0]']
#                                 8)
#
#  batch_normalization_44 (BatchN  (None, 960, 960, 12  512        ['conv2d_45[0][0]']
#  ormalization)                  8)
#
#  activation_44 (Activation)     (None, 960, 960, 12  0           ['batch_normalization_44[0][0]']
#                                 8)
#
#  conv2d_46 (Conv2D)             (None, 960, 960, 12  147584      ['activation_44[0][0]']
#                                 8)
#
#  batch_normalization_45 (BatchN  (None, 960, 960, 12  512        ['conv2d_46[0][0]']
#  ormalization)                  8)
#
#  activation_45 (Activation)     (None, 960, 960, 12  0           ['batch_normalization_45[0][0]']
#                                 8)
#
#  conv2d_transpose_10 (Conv2DTra  (None, 1920, 1920,   32832      ['activation_45[0][0]']
#  nspose)                        64)
#
#  concatenate_10 (Concatenate)   (None, 1920, 1920,   0           ['conv2d_transpose_10[0][0]',
#                                 128)                              'activation_23[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 1920, 1920,   73792       ['concatenate_10[0][0]']
#                                 64)
#
#  batch_normalization_46 (BatchN  (None, 1920, 1920,   256        ['conv2d_47[0][0]']
#  ormalization)                  64)
#
#  activation_46 (Activation)     (None, 1920, 1920,   0           ['batch_normalization_46[0][0]']
#                                 64)
#
#  conv2d_48 (Conv2D)             (None, 1920, 1920,   36928       ['activation_46[0][0]']
#                                 64)
#
#  batch_normalization_47 (BatchN  (None, 1920, 1920,   256        ['conv2d_48[0][0]']
#  ormalization)                  64)
#
#  activation_47 (Activation)     (None, 1920, 1920,   0           ['batch_normalization_47[0][0]']
#                                 64)
#
#  conv2d_49 (Conv2D)             (None, 1920, 1920,   65          ['activation_47[0][0]']
#                                 1)
#
# ==================================================================================================
# Total params: 497,766,849
# Trainable params: 497,718,209
# Non-trainable params: 48,640
# __________________________________________________________________________________________________

# %%
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
unet_result = unet_model.fit(images_train, masks_train, validation_split = 0.2, batch_size=1, epochs=20)
# Out:
# Epoch 1/20
# 12/12 [==============================] - 4s 364ms/step - loss: 0.5152 - accuracy: 0.7617 - val_loss: 0.6291 - val_accuracy: 0.6283
# Epoch 2/20
# 12/12 [==============================] - 4s 358ms/step - loss: 0.5152 - accuracy: 0.7617 - val_loss: 0.6105 - val_accuracy: 0.6507
# Epoch 3/20
# 12/12 [==============================] - 4s 358ms/step - loss: 0.5152 - accuracy: 0.7617 - val_loss: 0.5941 - val_accuracy: 0.6699
# Epoch 4/20
# 12/12 [==============================] - 4s 358ms/step - loss: 0.5152 - accuracy: 0.7617 - val_loss: 0.5796 - val_accuracy: 0.6863
# Epoch 5/20
# 12/12 [==============================] - 4s 358ms/step - loss: 0.5152 - accuracy: 0.7617 - val_loss: 0.5673 - val_accuracy: 0.7002
# Epoch 6/20
# 12/12 [==============================] - 4s 358ms/step - loss: 0.5152 - accuracy: 0.7617 - val_loss: 0.5560 - val_accuracy: 0.7120
# Epoch 7/20
# 12/12 [==============================] - 4s 358ms/step - loss: 0.5152 - accuracy: 0.7617 - val_loss: 0.5466 - val_accuracy: 0.7218
# Epoch 8/20
# 12/12 [==============================] - 4s 358ms/step - loss: 0.5152 - accuracy: 0.7617 - val_loss: 0.5387 - val_accuracy: 0.7300
# Epoch 9/20
# 12/12 [==============================] - 4s 358ms/step - loss: 0.5152 - accuracy: 0.7617 - val_loss: 0.5313 - val_accuracy: 0.7369
# Epoch 10/20
# 12/12 [==============================] - 4s 359ms/step - loss: 0.5152 - accuracy: 0.7617 - val_loss: 0.5253 - val_accuracy: 0.7427
# Epoch 11/20
# 12/12 [==============================] - 4s 358ms/step - loss: 0.5152 - accuracy: 0.7617 - val_loss: 0.5203 - val_accuracy: 0.7474
# Epoch 12/20
# 12/12 [==============================] - 4s 358ms/step - loss: 0.5152 - accuracy: 0.7617 - val_loss: 0.5155 - val_accuracy: 0.7514
# Epoch 13/20
# 12/12 [==============================] - 4s 359ms/step - loss: 0.5152 - accuracy: 0.7617 - val_loss: 0.5116 - val_accuracy: 0.7547
# Epoch 14/20
# 12/12 [==============================] - 4s 358ms/step - loss: 0.5152 - accuracy: 0.7617 - val_loss: 0.5085 - val_accuracy: 0.7573
# Epoch 15/20
# 12/12 [==============================] - 4s 358ms/step - loss: 0.5152 - accuracy: 0.7617 - val_loss: 0.5058 - val_accuracy: 0.7595
# Epoch 16/20
# 12/12 [==============================] - 4s 358ms/step - loss: 0.5152 - accuracy: 0.7617 - val_loss: 0.5033 - val_accuracy: 0.7613
# Epoch 17/20
# 12/12 [==============================] - 4s 359ms/step - loss: 0.5152 - accuracy: 0.7617 - val_loss: 0.5017 - val_accuracy: 0.7628
# Epoch 18/20
# 12/12 [==============================] - 4s 358ms/step - loss: 0.5152 - accuracy: 0.7617 - val_loss: 0.5002 - val_accuracy: 0.7640
# Epoch 19/20
# 12/12 [==============================] - 4s 358ms/step - loss: 0.5152 - accuracy: 0.7617 - val_loss: 0.4991 - val_accuracy: 0.7649
# Epoch 20/20
# 12/12 [==============================] - 4s 358ms/step - loss: 0.5152 - accuracy: 0.7617 - val_loss: 0.4977 - val_accuracy: 0.7656

# %%
unet_predict = unet_model.predict(images_test)
# Out:
# 1/1 [==============================] - 17s 17s/step

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 15995140068697516833
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 40129593344
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 9702400681681601234
#  physical_device_desc: "device: 0, name: NVIDIA A100-SXM4-40GB, pci bus id: 0000:00:04.0, compute capability: 8.0"
#  xla_global_id: 416903419]

# %%
unet_threshold = (unet_predict > 0.5).astype(np.uint8)

# %%
def show_result(og, unet, target):
    fig, axs = plt.subplots(1, 3, figsize=(10,5))
    axs[0].set_title("Original")
    axs[0].imshow(og)
    axs[0].axis('off')

    axs[1].set_title("U-Net")
    axs[1].imshow(unet)
    axs[1].axis('off')

    axs[2].set_title("Ground Truth")
    axs[2].imshow(target)
    axs[2].axis('off')

    plt.show()

# %%
for i in range(4):
    show_result(images_test[i], unet_threshold[i], masks_test[i])
